# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    from parameters import data_out_folder, min_assignees, min_issues_per_assignee, num_assignees, all_assignees
    print("Successfully imported configuration from parameters.py")
    print(f"Data folder: {data_out_folder}")
    # It's good practice to ensure data_out_folder exists early
    if not os.path.isdir(data_out_folder):
        print(f"Error: The data_out_folder '{data_out_folder}' specified in properties.py does not exist.")
        exit()
except ImportError:
    print("Error: Could not import 'properties.py'. Make sure it exists in the same directory and contains the necessary variables.")
    exit()
except AttributeError as e:
    print(f"Error: A required variable is missing from 'properties.py'. Ensure all are defined: {e}")
    exit()
# Out:
# Successfully imported configuration from parameters.py
# Data folder: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output

# %%
input_csv_path = os.path.join(data_out_folder, "issues_limited_user_cols.csv")
print(f"Reading data from: {input_csv_path}")
try:
    mongo_df = pd.read_csv(input_csv_path, sep='\t', encoding='utf-8')
except FileNotFoundError:
    print(f"Error: The input file '{input_csv_path}' was not found. Please ensure it exists.")
    exit()
mongo_df.drop(mongo_df.columns[mongo_df.columns.str.contains('unnamed', case=False)], axis=1, inplace=True, errors='ignore')
# Out:
# Reading data from: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\issues_limited_user_cols.csv

# %%
if 'assignee' in mongo_df.columns:
    mongo_df['assignee_id'] = mongo_df['assignee'].rank(method='dense').astype(int)
else:
    print("Error: 'assignee' column not found in the CSV. Cannot create 'assignee_id'.")
    exit()

# %%
rename_map = {
    '_id': 'id',
    'summary': 'title',
    'projectname': 'project_name'
    # Add other renames if necessary, ensure original columns exist
}
# Check if columns to be renamed actually exist before renaming
existing_columns_to_rename = {k: v for k, v in rename_map.items() if k in mongo_df.columns}
mongo_df.rename(columns=existing_columns_to_rename, inplace=True)


# Rearrange columns for better presentation of the data
# Ensure all these columns exist after renaming or were originally present
desired_columns_order = ['id', 'title', 'description', 'project_name', 'status_name', 
                         'priority_id', 'type_id', 'assignee_id', 'labels']
# Filter to keep only existing desired columns and reorder
actual_columns_to_use = [col for col in desired_columns_order if col in mongo_df.columns]
if len(actual_columns_to_use) != len(desired_columns_order):
    print(f"Warning: Not all desired columns for reordering were found. Using: {actual_columns_to_use}")
mongo_df = mongo_df[actual_columns_to_use]

# %%
print("Filtering issues with no titles or descriptions...")
# Check if 'title' and 'description' columns exist
if 'title' in mongo_df.columns and 'description' in mongo_df.columns:
    mongo_filtered_df = mongo_df[(mongo_df['description'].notna()) & (mongo_df['title'].notna())].copy() # Use .copy() to avoid SettingWithCopyWarning
else:
    print("Warning: 'title' or 'description' column not found. Skipping this filtering step.")
    mongo_filtered_df = mongo_df.copy()
print(f"Number of issues after initial text filtering: {len(mongo_filtered_df)}")
# Out:
# Filtering issues with no titles or descriptions...
# Number of issues after initial text filtering: 128853

# %%
print("Filtering projects based on assignee activity...")
projects_enough_issues_per_assignee = []
# Check if 'project_name' exists
if 'project_name' not in mongo_filtered_df.columns:
    print("Error: 'project_name' column not found. Cannot filter projects.")
    exit()
if 'assignee_id' not in mongo_filtered_df.columns: # Should exist from step 2
    print("Error: 'assignee_id' column not found. Cannot filter projects by assignee activity.")
    exit()

mongo_projects = mongo_filtered_df['project_name'].unique()

for project in mongo_projects:
    issues_single_project = mongo_filtered_df[mongo_filtered_df['project_name'] == project].copy()
    
    # Identify assignees with fewer than 'min_issues_per_assignee'
    assignee_counts = issues_single_project['assignee_id'].value_counts()
    removed_assignee_ids = assignee_counts[assignee_counts < min_issues_per_assignee].index.tolist()
    
    # Remove issues from these less active assignees
    issues_single_project = issues_single_project[~issues_single_project['assignee_id'].isin(removed_assignee_ids)]
    
    # Check if the project still has enough unique assignees
    if issues_single_project['assignee_id'].nunique() >= min_assignees:
        projects_enough_issues_per_assignee.append(project)
        print(f"  Project '{project}' QUALIFIED with {issues_single_project['assignee_id'].nunique()} active assignees.")
    else:
        print(f"  Project '{project}' NOT qualified. Assignees remaining: {issues_single_project['assignee_id'].nunique()}")

print(f"\nFound {len(projects_enough_issues_per_assignee)} projects with at least {min_assignees} assignees, each having at least {min_issues_per_assignee} issues:")
for p_name in projects_enough_issues_per_assignee:
    print(f"- {p_name}")
# Out:
# Filtering projects based on assignee activity...
#   Project 'AXIS' NOT qualified. Assignees remaining: 0
#   Project 'DERBY' NOT qualified. Assignees remaining: 0
#   Project 'XERCESJ' NOT qualified. Assignees remaining: 0
#   Project 'NUTCH' NOT qualified. Assignees remaining: 0
#   Project 'WODEN' NOT qualified. Assignees remaining: 0
#   Project 'OFBIZ' NOT qualified. Assignees remaining: 4
#   Project 'QPID' NOT qualified. Assignees remaining: 1
#   Project 'MAPREDUCE' NOT qualified. Assignees remaining: 0
#   Project 'CXF' NOT qualified. Assignees remaining: 2
#   Project 'AXIS2' NOT qualified. Assignees remaining: 0
#   Project 'ODE' NOT qualified. Assignees remaining: 0
#   Project 'IVY' NOT qualified. Assignees remaining: 0
#   Project 'HDFS' NOT qualified. Assignees remaining: 2
#   Project 'UIMA' NOT qualified. Assignees remaining: 0
#   Project 'HADOOP' NOT qualified. Assignees remaining: 3
#   Project 'TIKA' NOT qualified. Assignees remaining: 0
#   Project 'HBASE' NOT qualified. Assignees remaining: 0
#   Project 'VELTOOLS' NOT qualified. Assignees remaining: 0
#   Project 'VFS' NOT qualified. Assignees remaining: 0
#   Project 'TAP5' NOT qualified. Assignees remaining: 1
#   Project 'PDFBOX' NOT qualified. Assignees remaining: 2
#   Project 'RAT' NOT qualified. Assignees remaining: 0
#   Project 'ZOOKEEPER' NOT qualified. Assignees remaining: 0
#   Project 'SHIRO' NOT qualified. Assignees remaining: 0
#   Project 'PIG' NOT qualified. Assignees remaining: 0
#   Project 'YETUS' NOT qualified. Assignees remaining: 0
#   Project 'HIVE' QUALIFIED with 10 active assignees.
#   Project 'MAHOUT' NOT qualified. Assignees remaining: 0
#   Project 'BUILDR' NOT qualified. Assignees remaining: 0
#   Project 'LUCENE' NOT qualified. Assignees remaining: 0
#   Project 'SOLR' NOT qualified. Assignees remaining: 1
#   Project 'WICKET' NOT qualified. Assignees remaining: 1
#   Project 'CASSANDRA' QUALIFIED with 8 active assignees.
#   Project 'CLK' NOT qualified. Assignees remaining: 0
#   Project 'RAMPART' NOT qualified. Assignees remaining: 0
#   Project 'CMIS' NOT qualified. Assignees remaining: 0
#   Project 'YARN' NOT qualified. Assignees remaining: 1
#   Project 'LEGAL' NOT qualified. Assignees remaining: 0
#   Project 'VELOCITY' NOT qualified. Assignees remaining: 0
#   Project 'THRIFT' NOT qualified. Assignees remaining: 2
#   Project 'PIVOT' NOT qualified. Assignees remaining: 0
#   Project 'TS' NOT qualified. Assignees remaining: 3
#   Project 'LUCENENET' NOT qualified. Assignees remaining: 0
#   Project 'VXQUERY' NOT qualified. Assignees remaining: 0
#   Project 'AVRO' NOT qualified. Assignees remaining: 1
#   Project 'ACE' NOT qualified. Assignees remaining: 0
#   Project 'MAILBOX' NOT qualified. Assignees remaining: 0
#   Project 'AXIS2C' NOT qualified. Assignees remaining: 0
#   Project 'WW' NOT qualified. Assignees remaining: 1
#   Project 'IVYDE' NOT qualified. Assignees remaining: 0
#   Project 'COUCHDB' NOT qualified. Assignees remaining: 0
#   Project 'SLING' NOT qualified. Assignees remaining: 1
#   Project 'JS2' NOT qualified. Assignees remaining: 0
#   Project 'FELIX' NOT qualified. Assignees remaining: 0
#   Project 'FILEUPLOAD' NOT qualified. Assignees remaining: 0
#   Project 'HARMONY' NOT qualified. Assignees remaining: 0
#   Project 'SYNAPSE' NOT qualified. Assignees remaining: 0
#   Project 'DOSGI' NOT qualified. Assignees remaining: 0
#   Project 'PHOTARK' NOT qualified. Assignees remaining: 0
#   Project 'ESME' NOT qualified. Assignees remaining: 0
#   Project 'XERCESC' NOT qualified. Assignees remaining: 0
#   Project 'IBATIS' NOT qualified. Assignees remaining: 0
#   Project 'KARAF' NOT qualified. Assignees remaining: 1
#   Project 'ARIES' NOT qualified. Assignees remaining: 0
#   Project 'LOGCXX' NOT qualified. Assignees remaining: 0
#   Project 'OWB' NOT qualified. Assignees remaining: 0
#   Project 'STDCXX' NOT qualified. Assignees remaining: 0
#   Project 'FTPSERVER' NOT qualified. Assignees remaining: 0
#   Project 'GERONIMODEVTOOLS' NOT qualified. Assignees remaining: 0
#   Project 'SSHD' NOT qualified. Assignees remaining: 0
#   Project 'WINK' NOT qualified. Assignees remaining: 0
#   Project 'JCR' NOT qualified. Assignees remaining: 0
#   Project 'CAY' NOT qualified. Assignees remaining: 0
#   Project 'ROL' NOT qualified. Assignees remaining: 0
#   Project 'ETCH' NOT qualified. Assignees remaining: 0
#   Project 'WSS' NOT qualified. Assignees remaining: 0
#   Project 'APA' NOT qualified. Assignees remaining: 0
#   Project 'TUSCANY' NOT qualified. Assignees remaining: 0
#   Project 'GERONIMO' NOT qualified. Assignees remaining: 0
#   Project 'OODT' NOT qualified. Assignees remaining: 0
#   Project 'CONNECTORS' NOT qualified. Assignees remaining: 1
#   Project 'VYSPER' NOT qualified. Assignees remaining: 0
#   Project 'LANG' NOT qualified. Assignees remaining: 0
#   Project 'EXTSCRIPT' NOT qualified. Assignees remaining: 0
#   Project 'MYFACES' NOT qualified. Assignees remaining: 0
#   Project 'DIRSTUDIO' NOT qualified. Assignees remaining: 0
#   Project 'OPENJPA' NOT qualified. Assignees remaining: 0
#   Project 'PORTLETBRIDGE' NOT qualified. Assignees remaining: 0
#   Project 'OPENEJB' NOT qualified. Assignees remaining: 0
#   Project 'LIBCLOUD' NOT qualified. Assignees remaining: 0
#   Project 'LOG4PHP' NOT qualified. Assignees remaining: 0
#   Project 'JDO' NOT qualified. Assignees remaining: 0
#   Project 'MYFACESTEST' NOT qualified. Assignees remaining: 0
#   Project 'JSPWIKI' NOT qualified. Assignees remaining: 0
#   Project 'HUPA' NOT qualified. Assignees remaining: 0
#   Project 'WSCOMMONS' NOT qualified. Assignees remaining: 0
#   Project 'HAMA' NOT qualified. Assignees remaining: 0
#   Project 'LOG4J2' NOT qualified. Assignees remaining: 0
#   Project 'JEXL' NOT qualified. Assignees remaining: 0
#   Project 'JUDDI' NOT qualified. Assignees remaining: 0
#   Project 'RIVER' NOT qualified. Assignees remaining: 0
#   Project 'TRINIDAD' NOT qualified. Assignees remaining: 0
#   Project 'JAMES' NOT qualified. Assignees remaining: 0
#   Project 'TOMAHAWK' NOT qualified. Assignees remaining: 0
#   Project 'TILESSHARED' NOT qualified. Assignees remaining: 0
#   Project 'CLKE' NOT qualified. Assignees remaining: 0
#   Project 'DIR' NOT qualified. Assignees remaining: 0
#   Project 'DDLUTILS' NOT qualified. Assignees remaining: 0
#   Project 'PLUTO' NOT qualified. Assignees remaining: 0
#   Project 'WOOKIE' NOT qualified. Assignees remaining: 0
#   Project 'COMPRESS' NOT qualified. Assignees remaining: 0
#   Project 'DIGESTER' NOT qualified. Assignees remaining: 0
#   Project 'MATH' NOT qualified. Assignees remaining: 0
#   Project 'SIS' NOT qualified. Assignees remaining: 0
#   Project 'AMQ' NOT qualified. Assignees remaining: 1
#   Project 'AMQNET' NOT qualified. Assignees remaining: 0
#   Project 'OPENNLP' NOT qualified. Assignees remaining: 0
#   Project 'ZETACOMP' NOT qualified. Assignees remaining: 0
#   Project 'JENA' NOT qualified. Assignees remaining: 1
#   Project 'WHIRR' NOT qualified. Assignees remaining: 0
#   Project 'STANBOL' NOT qualified. Assignees remaining: 0
#   Project 'ABDERA' NOT qualified. Assignees remaining: 0
#   Project 'EXEC' NOT qualified. Assignees remaining: 0
#   Project 'IO' NOT qualified. Assignees remaining: 0
#   Project 'NPANDAY' NOT qualified. Assignees remaining: 0
#   Project 'KITTY' NOT qualified. Assignees remaining: 0
#   Project 'CAMEL' NOT qualified. Assignees remaining: 2
#   Project 'TILES' NOT qualified. Assignees remaining: 0
#   Project 'CLEREZZA' NOT qualified. Assignees remaining: 0
#   Project 'RAMPARTC' NOT qualified. Assignees remaining: 0
#   Project 'JDKIM' NOT qualified. Assignees remaining: 0
#   Project 'EMPIREDB' NOT qualified. Assignees remaining: 0
#   Project 'SHINDIG' NOT qualified. Assignees remaining: 0
#   Project 'CHUKWA' NOT qualified. Assignees remaining: 0
#   Project 'DTACLOUD' NOT qualified. Assignees remaining: 0
#   Project 'IMAP' NOT qualified. Assignees remaining: 0
#   Project 'CODEC' NOT qualified. Assignees remaining: 0
#   Project 'PROTOCOLS' NOT qualified. Assignees remaining: 0
#   Project 'TEXT' NOT qualified. Assignees remaining: 0
#   Project 'SANTUARIO' NOT qualified. Assignees remaining: 0
#   Project 'EASYANT' NOT qualified. Assignees remaining: 0
#   Project 'MRUNIT' NOT qualified. Assignees remaining: 0
#   Project 'NET' NOT qualified. Assignees remaining: 0
#   Project 'APLO' NOT qualified. Assignees remaining: 0
#   Project 'XMLSCHEMA' NOT qualified. Assignees remaining: 0
#   Project 'SCXML' NOT qualified. Assignees remaining: 0
#   Project 'DIRMINA' NOT qualified. Assignees remaining: 0
#   Project 'SMX4' NOT qualified. Assignees remaining: 0
#   Project 'NEETHI' NOT qualified. Assignees remaining: 0
#   Project 'WAVE' NOT qualified. Assignees remaining: 0
#   Project 'XALANC' NOT qualified. Assignees remaining: 0
#   Project 'CAUSEWAY' NOT qualified. Assignees remaining: 0
#   Project 'VCL' NOT qualified. Assignees remaining: 0
#   Project 'BVAL' NOT qualified. Assignees remaining: 0
#   Project 'AMQCPP' NOT qualified. Assignees remaining: 0
#   Project 'OLIO' NOT qualified. Assignees remaining: 0
#   Project 'MESOS' QUALIFIED with 14 active assignees.
#   Project 'OGNL' NOT qualified. Assignees remaining: 0
#   Project 'HTTPCLIENT' NOT qualified. Assignees remaining: 0
#   Project 'SCOUT' NOT qualified. Assignees remaining: 0
#   Project 'CELIX' NOT qualified. Assignees remaining: 0
#   Project 'KAFKA' NOT qualified. Assignees remaining: 1
#   Project 'HCATALOG' NOT qualified. Assignees remaining: 0
#   Project 'BOOKKEEPER' NOT qualified. Assignees remaining: 0
#   Project 'AIRAVATA' NOT qualified. Assignees remaining: 0
#   Project 'FLUME' NOT qualified. Assignees remaining: 0
#   Project 'OOZIE' NOT qualified. Assignees remaining: 0
#   Project 'JCS' NOT qualified. Assignees remaining: 0
#   Project 'BIGTOP' NOT qualified. Assignees remaining: 0
#   Project 'EMAIL' NOT qualified. Assignees remaining: 0
#   Project 'SM' NOT qualified. Assignees remaining: 0
#   Project 'RAVE' NOT qualified. Assignees remaining: 0
#   Project 'OCM' NOT qualified. Assignees remaining: 0
#   Project 'CHAIN' NOT qualified. Assignees remaining: 0
#   Project 'MTOMCAT' NOT qualified. Assignees remaining: 0
#   Project 'FUNCTOR' NOT qualified. Assignees remaining: 0
#   Project 'DIRSERVER' NOT qualified. Assignees remaining: 0
#   Project 'SQOOP' NOT qualified. Assignees remaining: 0
#   Project 'GORA' NOT qualified. Assignees remaining: 0
#   Project 'ACCUMULO' NOT qualified. Assignees remaining: 1
#   Project 'GIRAPH' NOT qualified. Assignees remaining: 0
#   Project 'TOMEE' NOT qualified. Assignees remaining: 0
#   Project 'INFRA' NOT qualified. Assignees remaining: 3
#   Project 'DIRECTMEMORY' NOT qualified. Assignees remaining: 0
#   Project 'ODFTOOLKIT' NOT qualified. Assignees remaining: 0
#   Project 'DROIDS' NOT qualified. Assignees remaining: 0
#   Project 'DIRAPI' NOT qualified. Assignees remaining: 0
#   Project 'AUTOTAG' NOT qualified. Assignees remaining: 0
#   Project 'CB' QUALIFIED with 5 active assignees.
#   Project 'ANY23' NOT qualified. Assignees remaining: 0
#   Project 'OLTU' NOT qualified. Assignees remaining: 0
#   Project 'DBUTILS' NOT qualified. Assignees remaining: 0
#   Project 'LUCY' NOT qualified. Assignees remaining: 0
#   Project 'LOG4NET' NOT qualified. Assignees remaining: 0
#   Project 'SANDBOX' NOT qualified. Assignees remaining: 0
#   Project 'BEANUTILS' NOT qualified. Assignees remaining: 0
#   Project 'OPENMEETINGS' NOT qualified. Assignees remaining: 1
#   Project 'COMDEV' NOT qualified. Assignees remaining: 0
#   Project 'AXIOM' NOT qualified. Assignees remaining: 0
#   Project 'TM' NOT qualified. Assignees remaining: 0
#   Project 'XMLBEANS' NOT qualified. Assignees remaining: 0
#   Project 'SYNCOPE' NOT qualified. Assignees remaining: 1
#   Project 'FLEX' NOT qualified. Assignees remaining: 1
#   Project 'TASHI' NOT qualified. Assignees remaining: 0
#   Project 'OAK' QUALIFIED with 5 active assignees.
#   Project 'KALUMET' NOT qualified. Assignees remaining: 0
#   Project 'PORTALS' NOT qualified. Assignees remaining: 0
#   Project 'AMBARI' QUALIFIED with 8 active assignees.
#   Project 'DELTASPIKE' NOT qualified. Assignees remaining: 0
#   Project 'WHISKER' NOT qualified. Assignees remaining: 0
#   Project 'CRUNCH' NOT qualified. Assignees remaining: 0
#   Project 'CTAKES' NOT qualified. Assignees remaining: 0
#   Project 'XALANJ' NOT qualified. Assignees remaining: 0
#   Project 'S4' NOT qualified. Assignees remaining: 0
#   Project 'CLOUDSTACK' NOT qualified. Assignees remaining: 1
#   Project 'PROTON' NOT qualified. Assignees remaining: 0
#   Project 'DAEMON' NOT qualified. Assignees remaining: 0
#   Project 'TST' NOT qualified. Assignees remaining: 0
#   Project 'BCEL' NOT qualified. Assignees remaining: 0
#   Project 'ONAMI' NOT qualified. Assignees remaining: 0
#   Project 'FEDIZ' NOT qualified. Assignees remaining: 0
#   Project 'MARMOTTA' NOT qualified. Assignees remaining: 0
#   Project 'HELIX' NOT qualified. Assignees remaining: 0
#   Project 'DRILL' NOT qualified. Assignees remaining: 2
#   Project 'HDT' NOT qualified. Assignees remaining: 0
#   Project 'CONFIGURATION' NOT qualified. Assignees remaining: 0
#   Project 'TAJO' NOT qualified. Assignees remaining: 0
#   Project 'KNOX' NOT qualified. Assignees remaining: 0
#   Project 'POOL' NOT qualified. Assignees remaining: 0
#   Project 'RIPPLE' NOT qualified. Assignees remaining: 0
#   Project 'MRQL' NOT qualified. Assignees remaining: 0
#   Project 'TEZ' NOT qualified. Assignees remaining: 0
#   Project 'FALCON' NOT qualified. Assignees remaining: 0
#   Project 'JCLOUDS' NOT qualified. Assignees remaining: 1
#   Project 'FOP' NOT qualified. Assignees remaining: 0
#   Project 'CLIMATE' NOT qualified. Assignees remaining: 0
#   Project 'TORQUE' NOT qualified. Assignees remaining: 0
#   Project 'DMAP' NOT qualified. Assignees remaining: 0
#   Project 'METAMODEL' NOT qualified. Assignees remaining: 0
#   Project 'SAMZA' NOT qualified. Assignees remaining: 0
#   Project 'OLINGO' NOT qualified. Assignees remaining: 0
#   Project 'STRATOS' NOT qualified. Assignees remaining: 0
#   Project 'CSV' NOT qualified. Assignees remaining: 0
#   Project 'CURATOR' NOT qualified. Assignees remaining: 0
#   Project 'TWILL' NOT qualified. Assignees remaining: 0
#   Project 'TATPI' NOT qualified. Assignees remaining: 0
#   Project 'STORM' NOT qualified. Assignees remaining: 1
#   Project 'DIRGROOVY' NOT qualified. Assignees remaining: 0
#   Project 'IMAGING' NOT qualified. Assignees remaining: 0
#   Project 'AURORA' NOT qualified. Assignees remaining: 0
#   Project 'DIRKRB' NOT qualified. Assignees remaining: 0
#   Project 'DATAFU' NOT qualified. Assignees remaining: 0
#   Project 'USERGRID' NOT qualified. Assignees remaining: 0
#   Project 'DISPATCH' NOT qualified. Assignees remaining: 0
#   Project 'PHOENIX' NOT qualified. Assignees remaining: 0
#   Project 'SENTRY' NOT qualified. Assignees remaining: 0
#   Project 'SPARK' QUALIFIED with 5 active assignees.
#   Project 'BATCHEE' NOT qualified. Assignees remaining: 0
#   Project 'WEAVER' NOT qualified. Assignees remaining: 0
#   Project 'STREAMS' NOT qualified. Assignees remaining: 0
#   Project 'SLIDER' NOT qualified. Assignees remaining: 0
#   Project 'XERCESP' NOT qualified. Assignees remaining: 0
#   Project 'FLINK' QUALIFIED with 47 active assignees.
#   Project 'CALCITE' NOT qualified. Assignees remaining: 3
#   Project 'PARQUET' NOT qualified. Assignees remaining: 0
#   Project 'STR' NOT qualified. Assignees remaining: 0
#   Project 'BROOKLYN' NOT qualified. Assignees remaining: 0
#   Project 'VALIDATOR' NOT qualified. Assignees remaining: 0
#   Project 'BLUR' NOT qualified. Assignees remaining: 0
#   Project 'RANGER' NOT qualified. Assignees remaining: 1
#   Project 'HTTPCORE' NOT qualified. Assignees remaining: 0
#   Project 'COLLECTIONS' NOT qualified. Assignees remaining: 0
#   Project 'CLI' NOT qualified. Assignees remaining: 0
#   Project 'LENS' NOT qualified. Assignees remaining: 0
#   Project 'IGNITE' QUALIFIED with 30 active assignees.
#   Project 'TAMAYA' NOT qualified. Assignees remaining: 0
#   Project 'REEF' NOT qualified. Assignees remaining: 0
#   Project 'NIFI' NOT qualified. Assignees remaining: 2
#   Project 'COMMONSSITE' NOT qualified. Assignees remaining: 0
#   Project 'KYLIN' NOT qualified. Assignees remaining: 0
#   Project 'HTRACE' NOT qualified. Assignees remaining: 0
#   Project 'COR' NOT qualified. Assignees remaining: 0
#   Project 'ORC' NOT qualified. Assignees remaining: 0
#   Project 'SAMOA' NOT qualified. Assignees remaining: 0
#   Project 'STEVE' NOT qualified. Assignees remaining: 0
#   Project 'TINKERPOP' NOT qualified. Assignees remaining: 1
#   Project 'COMMONSRDF' NOT qualified. Assignees remaining: 0
#   Project 'JCRVLT' NOT qualified. Assignees remaining: 0
#   Project 'MRM' NOT qualified. Assignees remaining: 0
#   Project 'CONTINUUM' NOT qualified. Assignees remaining: 0
#   Project 'MNG' NOT qualified. Assignees remaining: 0
#   Project 'MCHECKSTYLE' NOT qualified. Assignees remaining: 0
#   Project 'MCOMPILER' NOT qualified. Assignees remaining: 0
#   Project 'MDEPLOY' NOT qualified. Assignees remaining: 0
#   Project 'MDEP' NOT qualified. Assignees remaining: 0
#   Project 'DOXIA' NOT qualified. Assignees remaining: 0
#   Project 'MEAR' NOT qualified. Assignees remaining: 0
#   Project 'MENFORCER' NOT qualified. Assignees remaining: 0
#   Project 'MGPG' NOT qualified. Assignees remaining: 0
#   Project 'MRELEASE' NOT qualified. Assignees remaining: 0
#   Project 'MPIR' NOT qualified. Assignees remaining: 0
#   Project 'MSHADE' NOT qualified. Assignees remaining: 0
#   Project 'MSHARED' NOT qualified. Assignees remaining: 0
#   Project 'MSKINS' NOT qualified. Assignees remaining: 0
#   Project 'SUREFIRE' NOT qualified. Assignees remaining: 0
#   Project 'GROOVY' NOT qualified. Assignees remaining: 2
#   Project 'MINVOKER' NOT qualified. Assignees remaining: 0
#   Project 'SCM' NOT qualified. Assignees remaining: 0
#   Project 'ZEPPELIN' NOT qualified. Assignees remaining: 0
#   Project 'ARCHETYPE' NOT qualified. Assignees remaining: 0
#   Project 'TAVERNA' NOT qualified. Assignees remaining: 0
#   Project 'MASSEMBLY' NOT qualified. Assignees remaining: 0
#   Project 'GEODE' QUALIFIED with 12 active assignees.
#   Project 'MNGSITE' NOT qualified. Assignees remaining: 0
#   Project 'ARTEMIS' NOT qualified. Assignees remaining: 0
#   Project 'JELLY' NOT qualified. Assignees remaining: 0
#   Project 'BATIK' NOT qualified. Assignees remaining: 0
#   Project 'SINGA' NOT qualified. Assignees remaining: 0
#   Project 'POLYGENE' NOT qualified. Assignees remaining: 0
#   Project 'CXFXJC' NOT qualified. Assignees remaining: 0
#   Project 'TRAFODION' NOT qualified. Assignees remaining: 0
#   Project 'ATLAS' NOT qualified. Assignees remaining: 0
#   Project 'MJAR' NOT qualified. Assignees remaining: 0
#   Project 'MWAR' NOT qualified. Assignees remaining: 0
#   Project 'ASTERIXDB' NOT qualified. Assignees remaining: 1
#   Project 'MPLUGIN' NOT qualified. Assignees remaining: 0
#   Project 'SERF' NOT qualified. Assignees remaining: 0
#   Project 'MADLIB' NOT qualified. Assignees remaining: 0
#   Project 'QPIDJMS' NOT qualified. Assignees remaining: 0
#   Project 'SVN' NOT qualified. Assignees remaining: 0
#   Project 'MYRIAD' NOT qualified. Assignees remaining: 0
#   Project 'HAWQ' NOT qualified. Assignees remaining: 0
#   Project 'CONCERTED' NOT qualified. Assignees remaining: 0
#   Project 'MRAR' NOT qualified. Assignees remaining: 0
#   Project 'EAGLE' NOT qualified. Assignees remaining: 0
#   Project 'APEXCORE' NOT qualified. Assignees remaining: 0
#   Project 'MJARSIGNER' NOT qualified. Assignees remaining: 0
#   Project 'METRON' NOT qualified. Assignees remaining: 0
#   Project 'RYA' NOT qualified. Assignees remaining: 0
#   Project 'MYNEWT' NOT qualified. Assignees remaining: 0
#   Project 'S2GRAPH' NOT qualified. Assignees remaining: 0
#   Project 'APEXMALHAR' NOT qualified. Assignees remaining: 0
#   Project 'MJAVADOC' NOT qualified. Assignees remaining: 0
#   Project 'SYSTEMDS' NOT qualified. Assignees remaining: 0
#   Project 'MCHANGES' NOT qualified. Assignees remaining: 0
#   Project 'FREEMARKER' NOT qualified. Assignees remaining: 0
#   Project 'FINERACT' NOT qualified. Assignees remaining: 1
#   Project 'MYNEWTDOC' NOT qualified. Assignees remaining: 0
#   Project 'BEAM' NOT qualified. Assignees remaining: 4
#   Project 'ARROW' QUALIFIED with 25 active assignees.
#   Project 'KUDU' NOT qualified. Assignees remaining: 0
#   Project 'CMDA' NOT qualified. Assignees remaining: 0
#   Project 'EDGENT' NOT qualified. Assignees remaining: 0
#   Project 'WAGON' NOT qualified. Assignees remaining: 0
#   Project 'MNEMONIC' NOT qualified. Assignees remaining: 0
#   Project 'MINIFICPP' NOT qualified. Assignees remaining: 0
#   Project 'GEARPUMP' NOT qualified. Assignees remaining: 0
#   Project 'CRYPTO' NOT qualified. Assignees remaining: 0
#   Project 'OMID' NOT qualified. Assignees remaining: 0
#   Project 'MPLUGINTESTING' NOT qualified. Assignees remaining: 0
#   Project 'QUICKSTEP' NOT qualified. Assignees remaining: 0
#   Project 'MANT' NOT qualified. Assignees remaining: 0
#   Project 'GOSSIP' NOT qualified. Assignees remaining: 0
#   Project 'GUACAMOLE' NOT qualified. Assignees remaining: 0
#   Project 'CARBONDATA' NOT qualified. Assignees remaining: 0
#   Project 'TEPHRA' NOT qualified. Assignees remaining: 0
#   Project 'BAHIR' NOT qualified. Assignees remaining: 0
#   Project 'PIO' NOT qualified. Assignees remaining: 0
#   Project 'PIRK' NOT qualified. Assignees remaining: 0
#   Project 'UNOMI' NOT qualified. Assignees remaining: 0
#   Project 'DL' NOT qualified. Assignees remaining: 0
#   Project 'RNG' NOT qualified. Assignees remaining: 0
#   Project 'FLAGON' NOT qualified. Assignees remaining: 0
#   Project 'HIVEMALL' NOT qualified. Assignees remaining: 0
#   Project 'ARIA' NOT qualified. Assignees remaining: 0
#   Project 'TC' NOT qualified. Assignees remaining: 0
#   Project 'NETBEANS' NOT qualified. Assignees remaining: 2
#   Project 'XBEAN' NOT qualified. Assignees remaining: 0
#   Project 'TOREE' NOT qualified. Assignees remaining: 0
#   Project 'SPOT' NOT qualified. Assignees remaining: 0
#   Project 'ROCKETMQ' NOT qualified. Assignees remaining: 0
#   Project 'NUMBERS' NOT qualified. Assignees remaining: 0
#   Project 'DOXIASITETOOLS' NOT qualified. Assignees remaining: 0
#   Project 'WEEX' NOT qualified. Assignees remaining: 0
#   Project 'MRESOLVER' NOT qualified. Assignees remaining: 0
#   Project 'GRIFFIN' NOT qualified. Assignees remaining: 0
#   Project 'QPIDIT' NOT qualified. Assignees remaining: 0
#   Project 'GOBBLIN' NOT qualified. Assignees remaining: 0
#   Project 'IMPALA' QUALIFIED with 13 active assignees.
#   Project 'MINIFI' NOT qualified. Assignees remaining: 0
#   Project 'RATIS' NOT qualified. Assignees remaining: 0
#   Project 'HDDS' QUALIFIED with 22 active assignees.
#   Project 'ASFSITE' NOT qualified. Assignees remaining: 0
#   Project 'MANTRUN' NOT qualified. Assignees remaining: 0
#   Project 'LIVY' NOT qualified. Assignees remaining: 0
#   Project 'AMATERASU' NOT qualified. Assignees remaining: 0
#   Project 'DAFFODIL' NOT qualified. Assignees remaining: 0
#   Project 'MJLINK' NOT qualified. Assignees remaining: 0
#   Project 'MRESOURCES' NOT qualified. Assignees remaining: 0
#   Project 'JUNEAU' NOT qualified. Assignees remaining: 0
#   Project 'PLC4X' NOT qualified. Assignees remaining: 0
#   Project 'SCB' NOT qualified. Assignees remaining: 0
#   Project 'STATISTICS' NOT qualified. Assignees remaining: 0
#   Project 'MXNET' NOT qualified. Assignees remaining: 0
#   Project 'MSITE' NOT qualified. Assignees remaining: 0
#   Project 'NIFIREG' NOT qualified. Assignees remaining: 0
#   Project 'FINCN' NOT qualified. Assignees remaining: 0
#   Project 'DUBBO' NOT qualified. Assignees remaining: 0
#   Project 'NEMO' NOT qualified. Assignees remaining: 0
#   Project 'NETBEANSINFRA' NOT qualified. Assignees remaining: 0
#   Project 'GEOMETRY' NOT qualified. Assignees remaining: 0
#   Project 'SDAP' NOT qualified. Assignees remaining: 0
#   Project 'MPOM' NOT qualified. Assignees remaining: 0
#   Project 'DBCP' NOT qualified. Assignees remaining: 0
#   Project 'JOHNZON' NOT qualified. Assignees remaining: 0
#   Project 'MJDEPS' NOT qualified. Assignees remaining: 0
#   Project 'FC' NOT qualified. Assignees remaining: 0
#   Project 'CORAL' NOT qualified. Assignees remaining: 0
#   Project 'MARVIN' NOT qualified. Assignees remaining: 0
#   Project 'DATALAB' QUALIFIED with 9 active assignees.
#   Project 'MARCHETYPES' NOT qualified. Assignees remaining: 0
#   Project 'MPH' NOT qualified. Assignees remaining: 0
#   Project 'OPENOFFICE' NOT qualified. Assignees remaining: 1
#   Project 'IOTDB' QUALIFIED with 11 active assignees.
#   Project 'PINOT' NOT qualified. Assignees remaining: 0
#   Project 'CASSANDRASC' NOT qualified. Assignees remaining: 0
#   Project 'MSCRIPTING' NOT qualified. Assignees remaining: 0
#   Project 'SUBMARINE' NOT qualified. Assignees remaining: 2
#   Project 'CHAINSAW' NOT qualified. Assignees remaining: 0
#   Project 'HUDI' QUALIFIED with 7 active assignees.
#   Project 'TRAINING' NOT qualified. Assignees remaining: 0
#   Project 'MINDEXER' NOT qualified. Assignees remaining: 0
#   Project 'TUWENI' NOT qualified. Assignees remaining: 0
#   Project 'JOSHUA' NOT qualified. Assignees remaining: 0
#   Project 'MTOOLCHAINS' NOT qualified. Assignees remaining: 0
#   Project 'MPMD' NOT qualified. Assignees remaining: 0
#   Project 'DI' NOT qualified. Assignees remaining: 0
#   Project 'MILAGRO' NOT qualified. Assignees remaining: 0
#   Project 'MPDF' NOT qualified. Assignees remaining: 0
#   Project 'NIFILIBS' NOT qualified. Assignees remaining: 0
#   Project 'MINSTALL' NOT qualified. Assignees remaining: 0
#   Project 'CRAIL' NOT qualified. Assignees remaining: 0
#   Project 'CS' NOT qualified. Assignees remaining: 0
#   Project 'INLONG' NOT qualified. Assignees remaining: 1
#   Project 'STREAMPIPES' NOT qualified. Assignees remaining: 0
#   Project 'YUNIKORN' NOT qualified. Assignees remaining: 4
#   Project 'JXR' NOT qualified. Assignees remaining: 0
#   Project 'NLPCRAFT' NOT qualified. Assignees remaining: 0
#   Project 'INCUBATOR' NOT qualified. Assignees remaining: 0
#   Project 'MWRAPPER' NOT qualified. Assignees remaining: 0
#   Project 'SEDONA' NOT qualified. Assignees remaining: 0
#   Project 'LIMINAL' NOT qualified. Assignees remaining: 0
#   Project 'HOP' NOT qualified. Assignees remaining: 3
#   Project 'AGE2' NOT qualified. Assignees remaining: 0
#   Project 'WAYANG' NOT qualified. Assignees remaining: 0
#   Project 'INFRACLOUD1' NOT qualified. Assignees remaining: 0
#   Project 'MDOCCK' NOT qualified. Assignees remaining: 0
#   Project 'XGC' NOT qualified. Assignees remaining: 0
#   Project 'AWF' NOT qualified. Assignees remaining: 0
#   Project 'MBUILDCACHE' NOT qualified. Assignees remaining: 0
#   Project 'MARTIFACT' NOT qualified. Assignees remaining: 0
#   Project 'CELEBORN' NOT qualified. Assignees remaining: 1
#   Project 'MCLEAN' NOT qualified. Assignees remaining: 0
#   Project 'TOBAGO' NOT qualified. Assignees remaining: 0
#   Project 'LOGGING' NOT qualified. Assignees remaining: 0
#   Project 'CASSJAVA' NOT qualified. Assignees remaining: 0
#
# Found 16 projects with at least 5 assignees, each having at least 80 issues:
# - HIVE
# - CASSANDRA
# - MESOS
# - CB
# - OAK
# - AMBARI
# - SPARK
# - FLINK
# - IGNITE
# - GEODE
# - ARROW
# - IMPALA
# - HDDS
# - DATALAB
# - IOTDB
# - HUDI

# %%
print("\nProcessing and exporting data for qualified projects...")
for project_name in projects_enough_issues_per_assignee:
    print(f"\nProcessing project: {project_name}")
    
    # Determine the list of n_assignee values to iterate through
    n_assignees_list_for_project = all_assignees if project_name == "FLINK" else [num_assignees]
    
    for n_assignees_to_consider in n_assignees_list_for_project:
        print(f"  Considering top {n_assignees_to_consider} assignees...")
        
        # Create a DataFrame which contains the issues of this project (already filtered by active assignees in step 4 implicitly)
        # We should re-filter mongo_filtered_df to ensure we start with issues having titles/descriptions
        # then apply the assignee activity filter again for clarity or use the list of qualified assignees
        # For simplicity here, we'll take the original filtered issues and then select assignees.
        
        temp_project_df_all_issues = mongo_filtered_df[mongo_filtered_df['project_name'] == project_name].copy()

        # If we already filtered assignees in step 4, we should work with that set of assignees.
        # Re-calculate active assignees for this project (those meeting min_issues_per_assignee)
        assignee_counts_in_project = temp_project_df_all_issues['assignee_id'].value_counts()
        active_assignees_in_project = assignee_counts_in_project[assignee_counts_in_project >= min_issues_per_assignee].index.tolist()
        
        # Now, from these *active* assignees, select the top 'n_assignees_to_consider'
        # based on their issue counts within this active set.
        issues_from_active_assignees = temp_project_df_all_issues[temp_project_df_all_issues['assignee_id'].isin(active_assignees_in_project)]
        
        if issues_from_active_assignees.empty:
            print(f"    No issues found for active assignees in {project_name}. Skipping for {n_assignees_to_consider} assignees.")
            continue

        top_n_assignees_ids = issues_from_active_assignees['assignee_id'].value_counts().nlargest(n_assignees_to_consider).index.tolist()

        if not top_n_assignees_ids:
            print(f"    Could not select top {n_assignees_to_consider} assignees for {project_name} (perhaps not enough active assignees). Skipping.")
            continue
            
        print(f"    Selected {len(top_n_assignees_ids)} top assignees for this iteration.")

        # Keep only issues that have an id present in the top_n_assignees_ids list
        df_for_project_and_n_assignees = issues_from_active_assignees[issues_from_active_assignees['assignee_id'].isin(top_n_assignees_ids)].copy()

        if df_for_project_and_n_assignees.empty:
            print(f"    No issues after filtering for top {len(top_n_assignees_ids)} assignees in {project_name}. Skipping.")
            continue

        # Undersample the data
        # For assignees with 80 or more issues, sample 80. Keep all issues for others.
        # The constant '80' is hardcoded here as in your script.
        undersample_threshold = 80
        assignee_group_sizes = df_for_project_and_n_assignees.groupby('assignee_id')['assignee_id'].transform('size')
        
        msk_ge_threshold = assignee_group_sizes >= undersample_threshold
        
        df_undersampled_part = df_for_project_and_n_assignees[msk_ge_threshold].groupby('assignee_id', group_keys=False).sample(n=undersample_threshold, random_state=1) # Added random_state for reproducibility
        df_keep_all_part = df_for_project_and_n_assignees[~msk_ge_threshold]
        
        final_project_df = pd.concat([df_undersampled_part, df_keep_all_part], ignore_index=True)
        print(f"    Size of dataset for {project_name} with {n_assignees_to_consider} assignees after undersampling: {len(final_project_df)} issues.")

        # Write data to file
        output_filename = f"2_{project_name}_{n_assignees_to_consider}_assignees.csv"
        output_path = os.path.join(data_out_folder, output_filename)
        
        print(f"    Writing data to: {output_path}")
        try:
            final_project_df.to_csv(output_path, sep='\t', encoding='utf-8', index=False)
            print(f"    Successfully saved: {output_filename}")
        except Exception as e:
            print(f"    Error writing CSV file {output_filename}: {e}")

print("\nScript finished.")
# Out:
# Processing and exporting data for qualified projects...
#
# Processing project: HIVE
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for HIVE with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_HIVE_5_assignees.csv
#     Successfully saved: 2_HIVE_5_assignees.csv
#
# Processing project: CASSANDRA
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for CASSANDRA with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_CASSANDRA_5_assignees.csv
#     Successfully saved: 2_CASSANDRA_5_assignees.csv
#
# Processing project: MESOS
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for MESOS with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_MESOS_5_assignees.csv
#     Successfully saved: 2_MESOS_5_assignees.csv
#
# Processing project: CB
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for CB with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_CB_5_assignees.csv
#     Successfully saved: 2_CB_5_assignees.csv
#
# Processing project: OAK
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for OAK with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_OAK_5_assignees.csv
#     Successfully saved: 2_OAK_5_assignees.csv
#
# Processing project: AMBARI
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for AMBARI with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_AMBARI_5_assignees.csv
#     Successfully saved: 2_AMBARI_5_assignees.csv
#
# Processing project: SPARK
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for SPARK with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_SPARK_5_assignees.csv
#     Successfully saved: 2_SPARK_5_assignees.csv
#
# Processing project: FLINK
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for FLINK with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_FLINK_5_assignees.csv
#     Successfully saved: 2_FLINK_5_assignees.csv
#   Considering top 10 assignees...
#     Selected 10 top assignees for this iteration.
#     Size of dataset for FLINK with 10 assignees after undersampling: 800 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_FLINK_10_assignees.csv
#     Successfully saved: 2_FLINK_10_assignees.csv
#   Considering top 15 assignees...
#     Selected 15 top assignees for this iteration.
#     Size of dataset for FLINK with 15 assignees after undersampling: 1200 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_FLINK_15_assignees.csv
#     Successfully saved: 2_FLINK_15_assignees.csv
#   Considering top 20 assignees...
#     Selected 20 top assignees for this iteration.
#     Size of dataset for FLINK with 20 assignees after undersampling: 1600 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_FLINK_20_assignees.csv
#     Successfully saved: 2_FLINK_20_assignees.csv
#
# Processing project: IGNITE
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for IGNITE with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_IGNITE_5_assignees.csv
#     Successfully saved: 2_IGNITE_5_assignees.csv
#
# Processing project: GEODE
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for GEODE with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_GEODE_5_assignees.csv
#     Successfully saved: 2_GEODE_5_assignees.csv
#
# Processing project: ARROW
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for ARROW with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_ARROW_5_assignees.csv
#     Successfully saved: 2_ARROW_5_assignees.csv
#
# Processing project: IMPALA
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for IMPALA with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_IMPALA_5_assignees.csv
#     Successfully saved: 2_IMPALA_5_assignees.csv
#
# Processing project: HDDS
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for HDDS with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_HDDS_5_assignees.csv
#     Successfully saved: 2_HDDS_5_assignees.csv
#
# Processing project: DATALAB
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for DATALAB with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_DATALAB_5_assignees.csv
#     Successfully saved: 2_DATALAB_5_assignees.csv
#
# Processing project: IOTDB
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for IOTDB with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_IOTDB_5_assignees.csv
#     Successfully saved: 2_IOTDB_5_assignees.csv
#
# Processing project: HUDI
#   Considering top 5 assignees...
#     Selected 5 top assignees for this iteration.
#     Size of dataset for HUDI with 5 assignees after undersampling: 400 issues.
#     Writing data to: C:\Users\hp\Desktop\Module-3-Task-assigning\data\data_output\2_HUDI_5_assignees.csv
#     Successfully saved: 2_HUDI_5_assignees.csv
#
# Script finished.
